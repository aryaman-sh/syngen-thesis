# %%
import nibabel as nib
import os
import numpy as np
from glob import glob

dataDir = './dataset/augmented_dataset/all_plusEATT/'
# dataDir = './dataset/' # training data

img_path = dataDir + 'images/'
seg_path = dataDir + 'labels/'

print(img_path)
images = sorted(glob(os.path.join(img_path, '*BeLong_template_Warped_correct_spacing*')))
segmentations = sorted(glob(os.path.join(seg_path, '*BeLong_template_Warped_correct_spacing*')))
# Out:
# ./dataset/augmented_dataset/all_plusEATT/images/

# %%
for image in  images:
    data = nib.load(image).get_fdata()
    print(data.shape)
# Out:
# (104, 360, 360)
# (104, 360, 360)
# (104, 360, 360)
# (104, 360, 360)
# (104, 360, 360)
# (104, 360, 360)
# (104, 360, 360)
# (104, 360, 360)
# (104, 360, 360)
# (104, 360, 360)
# (104, 360, 360)
# (104, 360, 360)
# (104, 360, 360)
# (104, 360, 360)
# (104, 360, 360)
# (104, 360, 360)
# (104, 360, 360)
# (104, 360, 360)
# (104, 360, 360)
# (104, 360, 360)
# (104, 360, 360)

# %%
# TRAINING data - augmented dataset
# !python ./utils/pad_or_depad_image.py --path ./dataset/augmented_dataset/all_plusEATT/images/ --target_shape 192 360 360
# !python ./utils/pad_or_depad_image.py --path ./dataset/augmented_dataset/all_plusEATT/labels/ --target_shape 192 360 360
# Out:
# ['./dataset/augmented_dataset/all_plusEATT/images/sub-003_ses-01_acq-T2SPCDAFLSAG_T2w_reg_to_BeLong_template_Warped_correct_spacing.nii.gz', './dataset/augmented_dataset/all_plusEATT/images/sub-013_ses-01_acq-T2SPCDAFLSAG_T2w_reg_to_BeLong_template_Warped_correct_spacing.nii.gz', './dataset/augmented_dataset/all_plusEATT/images/sub-031_ses-01_acq-T2SPCDAFLSAG_T2w_reg_to_BeLong_template_Warped_correct_spacing.nii.gz', './dataset/augmented_dataset/all_plusEATT/images/sub-001_ses-01_acq-T2SPCDAFLSAG_T2w_reg_to_BeLong_template_Warped_correct_spacing.nii.gz', './dataset/augmented_dataset/all_plusEATT/images/sub-020_ses-01_acq-T2SPCDAFLSAG_T2w_reg_to_BeLong_template_Warped_correct_spacing.nii.gz', './dataset/augmented_dataset/all_plusEATT/images/sub-004_ses-01_acq-T2SPCDAFLSAG_T2w_reg_to_BeLong_template_Warped_correct_spacing.nii.gz', './dataset/augmented_dataset/all_plusEATT/images/sub-005_ses-01_acq-T2SPCDAFLSAG_T2w_reg_to_BeLong_template_Warped_correct_spacing.nii.gz', './dataset/augmen
# ...

# %% [markdown]
# # Check volume of Sydney segmentations

# %%
dataDir = './new_predictions/Sydney_T1w_corrected/NormSeg_2000e_unregistered_crop'
# dataDir = './dataset/' # training data


segmentations = sorted(glob(os.path.join(dataDir, '*.nii*')))

for seg in  segmentations:
    data = nib.load(seg).get_fdata()
    if np.sum(data[data!=0])>100000:
        print(seg)
# Out:
# ./new_predictions/Sydney_T1w_corrected/NormSeg_2000e_unregistered_crop/sub-000_T1w_reg-to-belong_Warped_padded_to_192_320_320.nii.gz
# ./new_predictions/Sydney_T1w_corrected/NormSeg_2000e_unregistered_crop/sub-008_T1w_reg-to-belong_Warped_padded_to_192_320_320.nii.gz
# ./new_predictions/Sydney_T1w_corrected/NormSeg_2000e_unregistered_crop/sub-011_T1w_reg-to-belong_Warped_padded_to_192_320_320.nii.gz
# ./new_predictions/Sydney_T1w_corrected/NormSeg_2000e_unregistered_crop/sub-020_T1w_reg-to-belong_Warped_padded_to_192_320_320.nii.gz
# ./new_predictions/Sydney_T1w_corrected/NormSeg_2000e_unregistered_crop/sub-027_T1w_reg-to-belong_Warped_padded_to_192_320_320.nii.gz
# ./new_predictions/Sydney_T1w_corrected/NormSeg_2000e_unregistered_crop/sub-033_T1w_reg-to-belong_Warped_padded_to_192_320_320.nii.gz
# ./new_predictions/Sydney_T1w_corrected/NormSeg_2000e_unregistered_crop/sub-035_T1w_reg-to-belong_Warped_padded_to_192_320_320.nii.gz
# ...
